# %% [markdown]
# # Loading Dataset for EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
happiness=pd.read_csv('happiness_score_dataset.csv')
happiness.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happiness.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
happiness.shape
# Out:
# (158, 12)

# %%
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# # Summary Statistics

# %%
happiness.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
happiness.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# ## Our purpose is to find out which factors (i.e. Economy, Health, Freedom, Trust and Generosity) are more important to live a happier life .  As a result, countries can focus on the more significant factors to achieve a higher happiness level.

# %%
# Renaming Specific Columns for ease of working
happiness.rename(columns={'Happiness Rank': 'Happiness_Rank', 'Happiness Score': 'Happiness_Score', 'Economy (GDP per Capita)': 'Economy', 'Health (Life Expectancy)': 'Health', 'Trust (Government Corruption)': 'Trust', 'Dystopia Residual': 'Dystopia_Residual'}, inplace=True)

# %%
happiness.columns
# Out:
# Index(['Country', 'Region', 'Happiness_Rank', 'Happiness_Score',
#        'Standard Error', 'Economy', 'Family', 'Health', 'Freedom', 'Trust',
#        'Generosity', 'Dystopia_Residual'],
#       dtype='object')

# %% [raw]
# # Country: Name of countries
# # Happiness Rank: Rank of the country based on the Happiness Score
# # Happiness Score: Happiness measurement on a scale of 0 to 10
# # Economy: The value of all final goods and services produced within a nation in a given year Per capita GDP is a measure of
# # the total output of a country that takes the gross domestic product (GDP) and divides it by the number of people in that
# # country. The per capita GDP is especially useful when comparing one country to another, because it shows the relative
# # performance of the countries.
# # Family: Importance of having a family
# # Health: Importance of health and amount of time prople expect to live
# # Freedom: Importance of freedom in each country
# # Trust: Perception of corruption in a government
# # Generosity: The quality of being kind and generous
# # Dystopia.Residual: Plays as a reference
#
# # Will deleting unnecessary columns (Standard Error)

# %% [markdown]
# # Data Visualizations

# %%
# installing and imporing important libraries
# !pip install folium
import folium
import json

# %%
# Creating a plain world map
world_map = folium.Map(
    zoom_start =4,
    tiles = 'cartodbpositron'
)

# Geojson file
country_geo = r'world-countries.json'

# generating choropleth map using the happiness rank
world_map.choropleth(
    geo_data = country_geo,
    data = happiness,
    columns = ['Country','Happiness_Rank'],
    key_on = 'feature.properties.name',
    legend_name = 'World Happiness Rank'
)

# display map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sns.catplot(x="Region", y="Happiness_Score", kind="box", height=15,aspect=3, data=happiness)
sns.set_context("paper", font_scale=2)

# %%
# histogram representation of dataset
happiness.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000285E844CE48>,
# ...
#       dtype=object)

# %%
country_wise = happiness[['Country', 'Health']]
country_wise.plot(kind = 'line',figsize=(20,8),color='g')
plt.title('Trend of Healthy (Life Expectancy) Across the World')
plt.ylabel("Health")
plt.xlabel("Country")
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.scatter(happiness['Economy'],happiness['Happiness_Score'])
plt.title("Economy (GDP per Capita) Vs Happiness Score ")
plt.ylabel("Happiness_Score")
plt.xlabel("Economy")
plt.show()

# plot shows it a lenier growth

# %%
#lets check how happiness score is changing with respect to freedom
plt.figure(figsize=(18,5))
sns.lineplot(x=happiness["Freedom"],y=happiness["Happiness_Score"],data=happiness)
plt.title("Freedom Vs Happiness Score ")
plt.ylabel("Happiness_Score")
plt.xlabel("Freedom")
plt.show()

# %%
plt.figure(figsize=(18,10))
sns.set()
sns.set_context("paper")
sns.swarmplot(x="Family", y="Happiness_Score", data=happiness)
plt.title("Family Vs Happiness Score ")
plt.ylabel("Happiness_Score")
plt.xlabel("Family")
plt.show()

# %%
#lets check how economy is changing with respect to government corruption
plt.figure(figsize=(18,10))
sns.lineplot(x=happiness["Trust"],y=happiness["Economy"],data=happiness)
plt.title("Trust (Government Corruption) Vs Economy (GDP per Capita) ")
plt.show()

# %%
plt.figure(figsize=(18,10))
plt.scatter(happiness['Generosity'],happiness['Happiness_Score'])
plt.title("Generosity Vs Happiness Score ")
plt.ylabel("Happiness_Score")
plt.xlabel("Generosity)")
plt.show()

# %%
country_wise = happiness[['Trust']]
country_wise.plot(kind = 'line',figsize=(20,8),color='r')
plt.title('Trend of Trust (Government Corruption) Across the World')
plt.show()

# %%
# Installing and importing important libraries for graphical representation 
# !pip install plotly==3.10
import plotly.plotly as po
import plotly.figure_factory as ff
import numpy as np
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
# ...
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
dataframe = happiness
data = dataframe.loc[:,["Happiness_Score", "Economy", "Family", "Health", "Freedom", "Trust", "Generosity", "Dystopia_Residual"]]
data["index"] = np.arange(1, len(data) + 1)

fig = ff.create_scatterplotmatrix(data, diag = 'box', index = 'index', colormap = 'Portland',
                                  colormap_type = 'cat',
                                  height = 1000, width = 1000)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="ff983ebd-3aab-4140-a127-d9b5a93c9a71" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ff983ebd-3aab-4140-a127-d9b5a93c9a71")) {
#                     Plotly.newPlot(
#                         'ff983ebd-3aab-4140-a127-d9b5a93c9a71',
# ...

# %% [markdown]
# # Bivariate Analysis

# %%
sns.pairplot(happiness)

# %% [markdown]
# # Checking null value if any

# %%
# checking if there are null values present in the dataset or not using heatmap
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,7))
sns.heatmap(happiness.isnull(),annot=True)
plt.show()

# %%
# Checking the null value without using visualization
happiness.isnull().sum()

# no missing dats present
# Out:
# Country              0
# Region               0
# Happiness_Rank       0
# Happiness_Score      0
# Standard Error       0
# Economy              0
# Family               0
# Health               0
# Freedom              0
# Trust                0
# Generosity           0
# Dystopia_Residual    0
# dtype: int64

# %%
happiness.shape
# Out:
# (158, 12)

# %%
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            158 non-null    object
#  1   Region             158 non-null    object
#  2   Happiness_Rank     158 non-null    int64
#  3   Happiness_Score    158 non-null    float64
#  4   Standard Error     158 non-null    float64
#  5   Economy            158 non-null    float64
#  6   Family             158 non-null    float64
#  7   Health             158 non-null    float64
#  8   Freedom            158 non-null    float64
#  9   Trust              158 non-null    float64
#  10  Generosity         158 non-null    float64
#  11  Dystopia_Residual  158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
happiness_data=happiness

# %%
happiness_data.shape
# Out:
# (158, 12)

# %%
#Importing label encoder to cenvert dtypes from object to numerical
from sklearn import preprocessing  
label_encoder = preprocessing.LabelEncoder() 
  
happiness_data['Country'] = label_encoder.fit_transform(happiness_data['Country'])
happiness_data['Region'] = label_encoder.fit_transform(happiness_data['Region'])

# %%
# dropping the columns
happiness_data.drop(['Standard Error','Happiness_Rank'], inplace=True, axis=1)

# %%
happiness_data.shape
# Out:
# (158, 10)

# %% [markdown]
# # Checking Correlation

# %%
dfcor=happiness.corr()
dfcor
# Out:
#                     Country    Region  Happiness_Score   Economy    Family  \
# Country            1.000000  0.005092         0.083380  0.037808  0.159416
# Region             0.005092  1.000000        -0.176791 -0.260139 -0.168533
# Happiness_Score    0.083380 -0.176791         1.000000  0.780966  0.740605
# Economy            0.037808 -0.260139         0.780966  1.000000  0.645299
# Family             0.159416 -0.168533         0.740605  0.645299  1.000000
# Health             0.037829 -0.357508         0.724200  0.816478  0.531104
# Freedom            0.085684  0.092567         0.568211  0.370300  0.441518
# Trust              0.088155  0.165040         0.395199  0.307885  0.205605
# Generosity         0.118085  0.273557         0.180319 -0.010465  0.087513
# Dystopia_Residual -0.019778 -0.057276         0.530474  0.040059  0.148117
#
#                      Health   Freedom     Trust  Generosity  Dystopia_Residual
# ...

# %%
# generating heatmap to check the correlation amount features
plt.figure(figsize=(12,7))
sns.heatmap(dfcor,cmap='ocean_r',linewidths=2,fmt=".2f",annot=True)

# dark colour represent positive correlation whereas lighter colour represent negative correlation
# happiness score reflect very positive correlation with Economy, Family, Health and Freedom

# %% [markdown]
# # Plotting Outliers

# %%
happiness_data.shape
# Out:
# (158, 10)

# %%
collist=happiness_data.columns.values
ncol=10
nrows=10

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(happiness_data[collist[i]],color='orange',orient='v')
    plt.tight_layout()

# %%
# Lets check whether there are outliners present in the dataset or not
from scipy.stats import zscore
z_score=abs(zscore(happiness_data))
print(happiness_data.shape)
df_happiness = happiness_data.loc[(z_score<3).all(axis=1)]
print(df_happiness.shape)
# outliners have been removed and the new shape of the dataset represent below
# Out:
# (158, 10)
# (152, 10)

# %% [markdown]
# # Checking if skewness is present in datset

# %%
df_happiness.skew()
# Below shows positive and negative skeweed data
# Out:
# Country              0.042505
# Region              -0.086220
# Happiness_Score      0.165587
# Economy             -0.401110
# Family              -0.815356
# Health              -0.733453
# Freedom             -0.406211
# Trust                1.287270
# Generosity           0.646579
# Dystopia_Residual   -0.045578
# dtype: float64

# %%
# plt.figure(figsize=(5*totalcol,5*totalcol))
plt.figure(figsize=(24,36))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df_happiness[collist[i]])

# %%
skew_happiness=df_happiness

# %%
skew_happiness.skew()
# Out:
# Country              0.042505
# Region              -0.086220
# Happiness_Score      0.165587
# Economy             -0.401110
# Family              -0.815356
# Health              -0.733453
# Freedom             -0.406211
# Trust                1.287270
# Generosity           0.646579
# Dystopia_Residual   -0.045578
# dtype: float64

# %%
# Treating skewness with log
import numpy as np
for col in skew_happiness.columns:
    if skew_happiness.skew().loc[col]>0.55:
        skew_happiness[col]=np.log1p(skew_happiness[col])

# %%
skew_happiness.skew()
# Out:
# Country              0.042505
# Region              -0.086220
# Happiness_Score      0.165587
# Economy             -0.401110
# Family              -0.815356
# Health              -0.733453
# Freedom             -0.406211
# Trust                1.108599
# Generosity           0.422071
# Dystopia_Residual   -0.045578
# dtype: float64

# %%
# Skewness still present, hence treating the skewness with Square Root Transform, it works for positive skewness only
list = ['Trust']
for i in list:
    skew_happiness[i]=np.sqrt(np.sqrt(skew_happiness[i]))

# %%
skew_happiness.skew()
# Out:
# Country              0.042505
# Region              -0.086220
# Happiness_Score      0.165587
# Economy             -0.401110
# Family              -0.815356
# Health              -0.733453
# Freedom             -0.406211
# Trust               -0.666597
# Generosity           0.422071
# Dystopia_Residual   -0.045578
# dtype: float64

# %% [markdown]
# # Seperating input and output variable for the regression problem

# %%
happiness_final=skew_happiness

# %%
happiness_final.columns
# Out:
# Index(['Country', 'Region', 'Happiness_Score', 'Economy', 'Family', 'Health',
#        'Freedom', 'Trust', 'Generosity', 'Dystopia_Residual'],
#       dtype='object')

# %%
# These variables do not make any direct impact to the happiness score hence droping them. 
happiness_final.drop(['Country','Region'], inplace=True, axis=1)

# %%
happiness_final.shape
# Out:
# (152, 8)

# %%
import numpy as np

# defining x variables
x=happiness_final.iloc[:,1:] 

# defining y variables
y=happiness_final.iloc[:,:1]

# %%
x.shape
# Out:
# (152, 7)

# %%
x.head()
# Out:
#    Economy   Family   Health  Freedom     Trust  Generosity  Dystopia_Residual
# 0  1.39651  1.34951  0.94143  0.66557  0.769436    0.259884            2.51738
# 1  1.30232  1.40223  0.94784  0.62877  0.603100    0.362070            2.70201
# 2  1.32548  1.36058  0.87464  0.64938  0.792498    0.293706            2.49204
# 3  1.45900  1.33095  0.88521  0.66973  0.746881    0.297872            2.46531
# 4  1.32629  1.32261  0.90563  0.63297  0.730560    0.377141            2.45176

# %%
y.shape
# Out:
# (152, 1)

# %%
y.head()
# Out:
#    Happiness_Score
# 0            7.587
# 1            7.561
# 2            7.527
# 3            7.522
# 4            7.427

# %%
# Scaling down using standardscaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[ 1.38120592,  1.36173566,  1.24883532, ...,  1.69093594,
#          0.59135845,  0.7472976 ],
#        [ 1.13920813,  1.57273597,  1.27511639, ...,  0.3551652 ,
#          1.67583434,  1.10115487],
#        [ 1.19871199,  1.40604092,  0.97499558, ...,  1.87613792,
#          0.95030431,  0.69873159],
#        ...,
#        [-1.38508144, -2.82729288, -1.36729975, ..., -0.05629815,
#          1.13625352, -0.33610398],
#        [-1.47030351, -2.62313647, -1.30272457, ..., -0.25705618,
#         -0.38680704, -0.94714645],
#        [-2.16746989, -2.37495496, -1.69279963, ..., -0.01947531,
#         -0.25596706, -0.56432974]])

# %%
# data is ready for machine learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import LinearRegression

max_r2_score=0
for r_state in range(42,101):
    x_train, x_test, y_train, y_test = train_test_split(x, y,random_state=r_state,test_size=0.20)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    y_pred = lr.predict(x_test)
    r2_scr = r2_score(y_test,y_pred)
    print("r2_score corresponding to random state: ",r_state," is: ",r2_scr)
    if r2_scr>max_r2_score:
        max_r2_score=r2_scr
        final_r_state=r_state
    print()
    print()
    print("max r2 score corresponding to ",final_r_state," is ",max_r2_score)
# Out:
# r2_score corresponding to random state:  42  is:  0.9985539614343325
#
#
# max r2 score corresponding to  42  is  0.9985539614343325
# r2_score corresponding to random state:  43  is:  0.995086735346597
#
#
# max r2 score corresponding to  42  is  0.9985539614343325
# r2_score corresponding to random state:  44  is:  0.9986174226009116
#
#
# max r2 score corresponding to  44  is  0.9986174226009116
# r2_score corresponding to random state:  45  is:  0.9979387435905317
#
#
# max r2 score corresponding to  44  is  0.9986174226009116
# r2_score corresponding to random state:  46  is:  0.9987109232422733
#
#
# max r2 score corresponding to  46  is  0.9987109232422733
# r2_score corresponding to random state:  47  is:  0.9982901613171541
#
#
# max r2 score corresponding to  46  is  0.9987109232422733
# r2_score corresponding to random state:  48  is:  0.9988820714715599
#
#
# max r2 score corresponding to  48  is  0.9988820714715599
# ...

# %%
# using corss_val_score to check the score of the regression
from sklearn.model_selection import cross_val_score
a_score=cross_val_score(lr,x,y,cv=5)
print(a_score)
print(a_score.mean())
print(np.std(a_score))
# Out:
# [0.92998421 0.9590887  0.87189801 0.94606334 0.98716486]
# 0.9388398263522628
# 0.03835918226524495

# %%
# checking with other Model
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=94)

# %%
x_train.shape
# Out:
# (118, 7)

# %%
y_train.shape
# Out:
# (118, 1)

# %%
x_test.shape
# Out:
# (34, 7)

# %%
x_test.shape
# Out:
# (34, 7)

# %%
# Importing important libraries
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso
from sklearn.ensemble import GradientBoostingRegressor

# %%
# finding best parameters for SVR using GridSearchCV
svr=SVR()
parameters={'kernel':('linear','ploy','rbf'), 'C':[1,10]}
svrgd=GridSearchCV(svr,parameters, cv=5)
svrgd.fit(x_train,y_train)
svrgd.best_params_
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
# finding best parameters for KNN using GridSearchCV
knn=KNeighborsRegressor()
parameters={'n_neighbors':range(1,29)}
knngd=GridSearchCV(knn,parameters, cv=5)
knngd.fit(x_train,y_train)
knngd.best_params_
# Out:
# {'n_neighbors': 5}

# %%
# finding best parameters for RandomForestRegressor using GridSearchCV
rfr=RandomForestRegressor()
parameters={'n_estimators':[100,199]}
rfrgd=GridSearchCV(rfr,parameters, cv=5)
rfrgd.fit(x_train,y_train)
rfrgd.best_params_
# Out:
# {'n_estimators': 100}

# %%
# finding best parameters for DecisionTreeRegressor using GridSearchCV
dtr=DecisionTreeRegressor()
parameters={'criterion':('mse', 'friedman_mse', 'mae')}
dtrgd=GridSearchCV(dtr,parameters, cv=5)
dtrgd.fit(x_train,y_train)
dtrgd.best_params_
# Out:
# {'criterion': 'mse'}

# %%
# finding best alpha value for lasso regression using GridSearchCV
lsor=Lasso()
parameters={'alpha':[0.001,0.01,0.1,1]}
lasgd=GridSearchCV(lsor,parameters, cv=5)
lasgd.fit(x_train,y_train)
lasgd.best_params_
# Out:
# {'alpha': 0.001}

# %%
# finding best parameters for gradient boosting using GridSearchCV
gbr=GradientBoostingRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000]}
gbrgd=GridSearchCV(gbr,parameters, cv=5)
gbrgd.fit(x_train,y_train)
gbrgd.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 1000}

# %%
lr = LinearRegression()
svr = SVR(C=10, kernel='linear')
dtr = DecisionTreeRegressor(criterion='mse')
knn = KNeighborsRegressor(n_neighbors=10)
rfr = RandomForestRegressor(n_estimators=199)
lsor = Lasso(alpha=0.001)
gbr = GradientBoostingRegressor(learning_rate=0.1, n_estimators=1000)

# %%
models = []
models.append(('LinearRegression', lr))
models.append(('SVR', svr))
models.append(('DecisionTreeRegressor', dtr))
models.append(('KNeighborsRegressor', knn))
models.append(('RandomForestRegressor', rfr))
models.append(('Lasso', lsor))
models.append(('GradientBoostingRegressor', gbr))

# %%
# Testing all required models with best parameters calculated

Model=[]
score=[]
rmse=[]
mae=[]
mse=[]
cvs=[]
std=[]

for name,model in models:
    print('********************',name,'**********************')
    print("\n")
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    predict=model.predict(x_test)
    print("\n")
    rscore=r2_score(y_test,predict)
    print("r2 Score =", rscore)
    score.append(rscore*100)
    print("\n")
    RMS=np.sqrt(mean_squared_error(y_test,predict))
    print("RMSE =", RMS)
    rmse.append(RMS*100)
    print("\n")
    MA=mean_absolute_error(y_test,predict)
    print("MAE =", MA)
    mae.append(MA*100)
    print("\n")
    MS=mean_squared_error(y_test,predict)
    print("MSE =", MS)
    mse.append(MS*100)
    print("\n")
    cvscore=cross_val_score(model, x, y, cv=5).mean()
    print("Cross_val_score =", cvscore)
    cvs.append(cvscore*100)
    print("\n")
    stdscore=cross_val_score(model, x, y, cv=5).std()
    print("Standard Deviation =", stdscore)
    std.append(stdscore*100)
    print("\n\n")
# Out:
# ******************** LinearRegression **********************
#
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
#
# r2 Score = 0.9991378507054675
#
#
# RMSE = 0.03441214345569604
#
#
# MAE = 0.02493159798299086
#
#
# MSE = 0.001184195617215404
#
#
# Cross_val_score = 0.9388398263522628
#
#
# Standard Deviation = 0.03835918226524495
#
#
#
# ******************** SVR **********************
#
#
# SVR(C=10, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
#
#
# r2 Score = 0.9974866970397229
#
#
# RMSE = 0.05875473982691484
#
#
# MAE = 0.05326091733849888
#
#
# MSE = 0.003452119452128453
#
#
# Cross_val_score = 0.9092928778166209
#
#
# Standard Deviation = 0.04547493592722336
#
#
#
# ******************** DecisionTreeRegressor **********************
#
#
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
# ...

# %%
import pandas as pd
result=pd.DataFrame({'Model': Model, 'r2_score': score, 'Root_mean_square': rmse,'Mean_absolute_error': mae, 'Mean_square_error': mse, 'Cross_val_score_mean':cvs, 'Cross_val_score_Std': std })
result
# Out:
#                        Model   r2_score  Root_mean_square  \
# 0           LinearRegression  99.913785          3.441214
# 1                        SVR  99.748670          5.875474
# 2      DecisionTreeRegressor  81.136968         50.900991
# 3        KNeighborsRegressor  89.385810         38.182461
# 4      RandomForestRegressor  91.177157         34.811662
# 5                      Lasso  99.911557          3.485394
# 6  GradientBoostingRegressor  94.116904         28.426504
#
#    Mean_absolute_error  Mean_square_error  Cross_val_score_mean  \
# 0             2.493160           0.118420             93.883983
# 1             5.326092           0.345212             90.929288
# 2            42.302941          25.909109           -748.639793
# 3            27.541471          14.579004           -492.956659
# 4            24.487408          12.118518           -324.232886
# 5             2.503133           0.121480             93.753929
# ...

# %%
# The above analysis shows that LinearRegression is giving the better result

# %%
from sklearn.externals import joblib
# Save the model as a pickle in a file 
joblib.dump(lr, 'Happiness_lr.csv')
# Out:
# ['Happiness_lr.csv']

# %%
model=joblib.load('Happiness_lr.csv')

# %%
model.predict(x_test)
# Out:
# array([[5.8978693 ],
#        [5.26890372],
#        [3.92668124],
#        [6.04121031],
#        [5.84841719],
#        [5.07552865],
#        [6.94569138],
#        [6.01945307],
#        [4.74277703],
#        [5.38909196],
#        [5.98017102],
#        [5.82006926],
#        [7.18976685],
#        [6.60502503],
#        [5.84228869],
#        [3.65281139],
#        [5.97934499],
#        [3.5945564 ],
#        [3.34665384],
#        [4.79863544],
#        [2.89237708],
#        [5.13791962],
#        [5.12417439],
#        [4.50229165],
#        [4.07388648],
#        [5.80454543],
#        [4.5338563 ],
#        [7.50498106],
#        [6.59643178],
#        [7.1828383 ],
#        [5.72881003],
#        [6.84116321],
#        [4.33443949],
#        [4.25895821]])
